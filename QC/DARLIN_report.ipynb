# %%
data_dir = "/storage/wangshouwenLab/wangshouwen/DATA/DARLIN/20220717_SC_3A/CC/DARLIN/results_cutoff_override_2"
Samples = "LL653-E1-P1-CC_S6,LL653-E1-P2-CC_S7"

# %%
from IPython.display import Image, display;
SampleList=sorted(Samples.split(','))
import pandas as pd
import os
pd.set_option('display.max_columns', None)

# %%
pd.read_csv(f'{data_dir}/merge_all/refined_results.csv',index_col=0)
# Out:
#                 sample  tot_fastq_N  edit_read_fraction  read_threshold  \
# 0    LL653-E1-P1-CC_S6     640978.0           40.000000             2.0
# 1    LL653-E1-P2-CC_S7      46504.0           16.000000             2.0
# 2    LL653-E1-P3-CC_S8    1041631.0           44.000000             2.0
# 3    LL653-E6-P1-CC_S9      67746.0           24.000000             2.0
# 4   LL653-E6-P2-CC_S10      40317.0           11.000000             2.0
# 5       LL719-P1-CC_S1      53341.0           16.000000             2.0
# 6       LL719-P2-CC_S2      76959.0           15.000000             2.0
# 7       LL731-P1-CC_S3      37943.0            7.000000             2.0
# 8       LL731-P2-CC_S4      57897.0            7.000000             2.0
# 9       LL731-P3-CC_S5     165484.0           36.000000             2.0
# 10     LL749-4E-CC_S11      43914.0            4.000000             2.0
# 0            merge_all    2272714.0           36.562515             2.0
#
# ...

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
display(Image(filename=f'{data_dir}/merge_all/view_data_across_samples_edit_tag_fraction.png'))

# %%
display(Image(filename=f'{data_dir}/merge_all/view_data_across_samples_eventful.png'))

# %%
for sample in SampleList:
    #print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    print(f"\n----------------------- Sample: {sample} --------------------------\n")
    if os.path.exists(f'{data_dir}/{sample}/Alleles.png'):
        display(Image(filename=f'{data_dir}/{sample}/Alleles.png'))
# Out:
# ----------------------- Sample: LL653-E1-P1-CC_S6 --------------------------
# ----------------------- Sample: LL653-E1-P2-CC_S7 --------------------------

# %%
for sample in SampleList:
    #print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    print(f"\n----------------------- Sample: {sample} --------------------------\n")
    if os.path.exists(f'{data_dir}/{sample}/plot_site_decomposition.png'):
        display(Image(filename=f'{data_dir}/{sample}/plot_site_decomposition.png'))
# Out:
# ----------------------- Sample: LL653-E1-P1-CC_S6 --------------------------
# ----------------------- Sample: LL653-E1-P2-CC_S7 --------------------------

# %%
for sample in SampleList:
    #print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    print(f"\n----------------------- Sample: {sample} --------------------------\n")
    if os.path.exists(f'{data_dir}/{sample}/plot_indel_freq_vs_length.png'):
        display(Image(filename=f'{data_dir}/{sample}/plot_indel_freq_vs_length.png'))
# Out:
# ----------------------- Sample: LL653-E1-P1-CC_S6 --------------------------
# ----------------------- Sample: LL653-E1-P2-CC_S7 --------------------------

# %%
# for sample in SampleList:
    #print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
#    print(f"\n----------------------- Sample: {sample} --------------------------\n")
#     display(Image(filename=f'{data_dir}/{sample}/plot_stargate.png'))

# %%
for sample in SampleList:
    print(f"\n----------------------- Sample: {sample} --------------------------\n")
    if os.path.exists(f'{data_dir}/{sample}/cumulative_indel_freq.png'):
        display(Image(filename=f'{data_dir}/{sample}/cumulative_indel_freq.png'))
# Out:
# ----------------------- Sample: LL653-E1-P1-CC_S6 --------------------------
# ----------------------- Sample: LL653-E1-P2-CC_S7 --------------------------

# %%
if os.path.exists(f'{data_dir}/merge_all/allele_breakdown_by_sample.png'):
    display(Image(filename=f'{data_dir}/merge_all/allele_breakdown_by_sample.png'))

# %%
if os.path.exists(f'{data_dir}/merge_all/all_insertion_pattern.png'):
    display(Image(filename=f'{data_dir}/merge_all/all_insertion_pattern.png'))
