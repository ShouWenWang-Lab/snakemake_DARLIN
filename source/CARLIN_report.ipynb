# %%
data_dir='/n/data1/bch/hemonc/camargo/li/DATA/CARLIN/20211010_3_pulses_cCARLIN/CARLIN/results_cutoff_override_10'
Samples='LL605-HSC_S4,LL605-LK_S3'

# %%
from IPython.display import Image, display;
SampleList=sorted(Samples.split(','))
import pandas as pd
import os

# %%
pd.read_csv(f'{data_dir}/merge_all/refined_results.csv',index_col=0)
# Out:
#       sample  tot_fastq_N  edit_read_fraction  read_threshold  UMI_eventful  \
# 0       test         9987               46.23               4           120
# 1  merge_all         9987               46.23               4           120
#
#    UMI_called  Mean_read_per_edited_UMI  Mean_read_per_unedited_UMI  \
# 0         256                      4.49                           5
# 1         256                      4.49                           5
#
#    edit_UMI_fraction  total_alleles  ...  effective_allele_N  \
# 0              46.88             22  ...                   5
# 1              46.88             22  ...                   5
#
#    Diversity_index_all  Diversity_index_edited  CARLIN_potential_by_UMI  \
# 0                 0.02                    0.04                     9.44
# 1                 0.02                    0.04                     9.44
#
#    CARLIN_potential_by_allel  ins_del_ratio_ratio_by_eventful_UMI  \
# 0                          8                                 1.22
# 1                          8                                 1.22
#
#    ins_del_ratio_by_allele  ave_insert_len  ave_del_len  source
# 0                      2.1            3.63         9.15      te
# 1                      2.1            3.63         9.15      me
#
# [2 rows x 21 columns]

# %%
display(Image(filename=f'{data_dir}/merge_all/view_data_across_samples_edit_UMI_fraction.png'))

# %%
for sample in SampleList:
    print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    display(Image(filename=f'{data_dir}/{sample}/Alleles.png'))
# Out:
# ----------------------- Sample: test --------------------------

# %%
for sample in SampleList:
    print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    display(Image(filename=f'{data_dir}/{sample}/plot_site_decomposition.png'))
# Out:
# ----------------------- Sample: test --------------------------

# %%
for sample in SampleList:
    print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    display(Image(filename=f'{data_dir}/{sample}/plot_indel_freq_vs_length.png'))
# Out:
# ----------------------- Sample: test --------------------------

# %%
for sample in SampleList:
    print(f"\n----------------------- Sample: {sample.split('_')[0]} --------------------------\n")
    display(Image(filename=f'{data_dir}/{sample}/plot_stargate.png'))
# Out:
# ----------------------- Sample: test --------------------------

# %%
display(Image(filename=f'{data_dir}/merge_all/allele_breakdown_by_sample.png'))

# %%
display(Image(filename=f'{data_dir}/merge_all/all_insertion_pattern.png'))
